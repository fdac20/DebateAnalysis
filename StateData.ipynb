# %%
import pandas as pd
import wikipedia as wp
import numpy as np
import matplotlib.pyplot as plt
html = "https://en.wikipedia.org/wiki/List_of_United_States_presidential_election_results_by_state"
 
df = pd.read_html(html, header=0)[0]  

df.drop(df.index[range(52,98)], inplace=True)
states = df['State']
debateyears = ["1960", "1976", "1980", "1984", "1988", "1992", "1996", "2000 ‡", "2004", "2008", "2012", "2016 ‡"]
Debateyears = [1960, 1976, 1980, 1984, 1988, 1992, 1996, 2000 , 2004, 2008, 2012, 2016]
wins = ["D", "D", "R", "R", "R", "D", "D", "R", "R", "D", "D", "R"]
swingstates = ["Florida", "Iowa", "Michigan", "Minnesota", "Nevada", "New Hampshire", "North Carolina", "Ohio", "Pennsylvania", "Virginia", "Wisconsin"]
Demyears = []
Repyears = []
SDemyears = []
SRepyears = []

# %%
for year, win in zip(debateyears, wins):
    Dem = 0
    Rep = 0
    Dsstates = 0
    Rsstates = 0
    for i in range(52):
        Rhit = 0
        Dhit = 0
        if df[year][i] == "D":
            Dem+=1
            Dhit=1
        elif df[year][i] == "R":
            Rep+=1
            Rhit=1
        for sstate in swingstates:
            if states[i] == sstate and Dhit == 1:
                Dsstates+=1
            elif states[i] == sstate and Rhit == 1:
                Rsstates+=1

    print(year, "\n\nDemocrat Won States:", Dem, "Republican Won States: ", Rep, "\nDemocrat Won Swing States:", Dsstates, "Republican Won Swing States: ", Rsstates)
    Demyears.append(Dem)
    Repyears.append(Rep)
    SDemyears.append(Dsstates)
    SRepyears.append(Rsstates)
    if win == "D":
        print("Democrat Won Election\n")
    elif win == "R":
        print("Republican Won Election\n")
# Out:
# 1960
#
# Democrat Won States: 22 Republican Won States:  26
# Democrat Won Swing States: 5 Republican Won Swing States:  6
# Democrat Won Election
#
# 1976
#
# Democrat Won States: 24 Republican Won States:  27
# Democrat Won Swing States: 6 Republican Won Swing States:  5
# Democrat Won Election
#
# 1980
#
# Democrat Won States: 7 Republican Won States:  44
# Democrat Won Swing States: 1 Republican Won Swing States:  10
# Republican Won Election
#
# 1984
#
# Democrat Won States: 2 Republican Won States:  49
# Democrat Won Swing States: 1 Republican Won Swing States:  10
# Republican Won Election
#
# 1988
#
# Democrat Won States: 11 Republican Won States:  40
# Democrat Won Swing States: 3 Republican Won Swing States:  8
# Republican Won Election
#
# 1992
#
# Democrat Won States: 33 Republican Won States:  18
# Democrat Won Swing States: 8 Republican Won Swing States:  3
# Democrat Won Election
#
# 1996
#
# Democrat Won States: 32 Republican Won States:  19
# Democrat Won Swing States: 9 Republican Won Swing States:  2
# Democrat Won Election
#
# 2000 ‡
#
# Democrat Won States: 21 Republican Won States:  30
# Democrat Won Swing States: 5 Republican Won Swing States:  6
# Republican Won Election
#
# 2004
#
# Democrat Won States: 20 Republican Won States:  31
# Democrat Won Swing States: 5 Republican Won Swing States:  6
# Republican Won Election
#
# 2008
#
# Democrat Won States: 29 Republican Won States:  22
# Democrat Won Swing States: 11 Republican Won Swing States:  0
# Democrat Won Election
#
# 2012
#
# Democrat Won States: 27 Republican Won States:  24
# Democrat Won Swing States: 10 Republican Won Swing States:  1
# Democrat Won Election
#
# 2016 ‡
#
# Democrat Won States: 21 Republican Won States:  30
# Democrat Won Swing States: 4 Republican Won Swing States:  7
# Republican Won Election

# %%
plt.plot(Debateyears, Demyears, "bo")
plt.title("Democrat States Won by Year")
plt.xlabel("Debate Year")
plt.ylabel("States Won")
plt.show()

plt.plot(Debateyears, Repyears, "bo")
plt.title("Republican States Won by Year")
plt.xlabel("Debate Year")
plt.ylabel("States Won")
plt.show()

plt.plot(Debateyears, SDemyears, "bo")
plt.title("Democrat Swing States Won by Year")
plt.xlabel("Debate Year")
plt.ylabel("Swing States Won")
plt.show()

plt.plot(Debateyears, SRepyears, "bo")
plt.title("Republican Swing States Won by Year")
plt.xlabel("Debate Year")
plt.ylabel("Swing States Won")
plt.show()

# %%
for i, state in zip(range(52), states):
    Dem = 0
    Rep = 0

    for year in debateyears:
        if df[year][i] == "D":
            Dem+=1
            Dhit=1
        elif df[year][i] == "R":
            Rep+=1
            Rhit=1


    print(state, "\nTimes Voted Democrat:", Dem, "Times Votes Republican: ", Rep, "\n")
# Out:
# Alabama
# Times Voted Democrat: 1 Times Votes Republican:  10
#
# Alaska
# Times Voted Democrat: 0 Times Votes Republican:  12
#
# Arizona
# Times Voted Democrat: 1 Times Votes Republican:  11
#
# Arkansas
# Times Voted Democrat: 4 Times Votes Republican:  8
#
# California
# Times Voted Democrat: 7 Times Votes Republican:  5
#
# Colorado
# Times Voted Democrat: 4 Times Votes Republican:  8
#
# Connecticut
# Times Voted Democrat: 8 Times Votes Republican:  4
#
# Delaware
# Times Voted Democrat: 9 Times Votes Republican:  3
#
# D.C.
# Times Voted Democrat: 11 Times Votes Republican:  0
#
# Florida
# Times Voted Democrat: 4 Times Votes Republican:  8
#
# Georgia
# Times Voted Democrat: 4 Times Votes Republican:  8
#
# Hawaii
# Times Voted Democrat: 11 Times Votes Republican:  1
#
# Idaho
# Times Voted Democrat: 0 Times Votes Republican:  12
#
# Illinois
# Times Voted Democrat: 8 Times Votes Republican:  4
#
# Indiana
