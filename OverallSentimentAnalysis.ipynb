# %%
import nltk 
#nltk.download('vader_lexicon') # one time only
from nltk.sentiment.vader import SentimentIntensityAnalyzer
vader = SentimentIntensityAnalyzer() # or whatever you want to call it

# %%
import requests, re, nltk
from bs4 import BeautifulSoup
from nltk import clean_html
from collections import Counter
import operator

# We most likely would like to remove html markup
def cleanHtml (html):
    from bs4 import BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')
    return soup .get_text()

# We also want to remove special characters, quotes, etc. from each word
def cleanWord (w):
    # r in r'[.,"\']' tells to treat \ as a regular character 
    # but we need to escape ' with \'
    # any character between the brackets [] is to be removed 
    wn = re.sub('[\–,"\.\'&\|@>*;/=]', "", w)
    # get rid of numbers
    return re.sub('^[0-9\.]*$', "", wn)

def debate_word_list (URL, name1, name2, modList):
    # first get the web page
    r = requests .get(URL)
    
    # Now clean
    # remove html markup
    t = cleanHtml (r .text) .lower()
    
    # split string into an array of words using any sequence of spaces "\s+" 
    wds = re .split('\s+',t)
    
    
    
    # remove periods, commas, etc stuck to the edges of words
    for i in range(len(wds)):
        wds[i] = cleanWord (wds [i])
        
    name1Arr = []
    name2Arr = []
    switcher = 3
            
    for i in range(len(wds)):
        if wds[i] == name1:
            switcher = 1
            
        elif wds[i] == name2:
            switcher = 2
            
        elif wds[i] in modList:
            switcher = 3
            
        else:
            if switcher == 1:
                name1Arr.append(wds[i])
                
            elif switcher == 2:
                name2Arr.append(wds[i])
                
    return [name1Arr, name2Arr]

debateArrSent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/september-26-1960-debate-transcript/', "kennedy:", "nixon:", ['smith:', 'vanocur:', 'novins:', 'warren:', 'fleming:'])

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-7-1960-debate-transcript/', "kennedy:", "nixon:", ['mcgee:', 'nivem:', 'morgan:', 'spivak:', 'levy:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-13-1960-debate-transcript/', "kennedy:", "nixon:", ['shadel:', 'mcgee:', 'fremd:', 'cater:', 'drummond:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-21-1960-debate-transcript/', "kennedy:", "nixon:", ['howe:', 'singiser:', 'cronkite:', 'chancellor:'])                
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/september-23-1976-debate-transcript/', "carter:", "ford:", ['reynolds:', 'newman:', 'gannon:', 'drew:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-6-1976-debate-transcript/', "carter:", "ford:", ['valeriani:', 'frederick:', 'frankel:', 'trewhitt:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-22-1976-debate-transcript/', "carter:", "ford:", ['walters:', 'kraft:', 'maynard:', 'nelson:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-28-1980-debate-transcript/', "reagan:", "carter:", ['hinerfeld:', 'stone:', 'smith:', 'ellis:', 'hilliard:', 'walters:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debate2ArrSent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-7-1984-debate-transcript/', "president:", "mondale:", ['wieghart:', 'walters:', 'sawyer:', 'barnes:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-21-1984-debate-transcript/', "president:", "mondale:", ['ridings:', 'newman:', 'geyer:', 'kalb:', 'kondracke:', 'audience member:', 'trewhitt:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/september-25-1988-debate-transcript/', "bush:", "dukakis:", ['lehrer:', 'mashek:', 'groer:', 'jennings:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-13-1988-debate-transcript/', "bush:", "dukakis:", ['shaw:', 'compton:', 'warner:', 'mitchell:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-11-1992-first-half-debate-transcript/',  "clinton:", "bush:", ['lehrer:', 'compton:', 'sander vanocur:', 'vanocur:', 'mashek:', "perot:"])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-11-1992-second-half-debate-transcript/',  "clinton:", "bush:", ['lehrer:', 'compton:', 'sander vanocur:', 'vanocur:', 'perot:','mashek:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-15-1992-first-half-debate-transcript/',  "clinton:", "bush:", ['carole simpson:', 'audience question:', 'simpson:', 'perot:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-11-1992-second-half-debate-transcript/',  "clinton:", "bush:", ['carole simpson:', 'audience question:', 'simpson:', "perot:"])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-6-1996-debate-transcript/', 'clinton:', 'dole:', ['lehrer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-6-1996-debate-transcript/', 'clinton:', 'dole:', ['lehrer:', 'ms. mcafee:', 'dr. berkley:', 'mr. milligan:', 'ms. kelly:', 'mr. delgado:', 'mr. fleck:', 
'ms. gonzalez:', 'ms. johnson:', 'ms. naudin:', 'ms. sanders:', 'mr. david:', 'mr. burns:', 'ms. giannotti:', 'mr. goldfarb:', 'ms. strategos:', 'MS. O’CONNOR:', 'MS. SIEFERT:', 'MR. SMITH:', 'MR. KITE:', 'ms. dube:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-3-2000-transcript/', 'bush:', 'gore:', ['moderator:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-11-2000-debate-transcript/', 'bush:', 'gore:', ['moderator:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-17-2000-debate-transcript/', 'bush:', 'gore:', ['moderator:', 'member of audience:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/september-30-2004-debate-transcript/', 'bush:', 'kerry:', ['lehrer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-8-2004-debate-transcript/', 'bush:', 'kerry:', ['gibson:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-13-2004-debate-transcript/', 'bush:', 'kerry:', ['schieffer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/2008-debate-transcript/', 'obama:', 'mccain:', ['lehrer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list  ('https://www.debates.org/voter-education/debate-transcripts/october-7-2008-debate-transcrip/', 'obama:', 'mccain:', ['brokaw:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list('https://www.debates.org/voter-education/debate-transcripts/october-15-2008-debate-transcript/', 'obama:', 'mccain:', ['schieffer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-3-2012-debate-transcript/', 'obama:', 'romney:', ['lehrer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list  ('https://debates.org/voter-education/debate-transcripts/october-16-2012-the-second-obama-romney-presidential-debate/', 'obama:', 'romney:', ['crowley:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list('https://debates.org/voter-education/debate-transcripts/october-22-2012-the-third-obama-romney-presidential-debate/', 'obama:', 'romney:', ['schieffer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/september-26-2016-debate-transcript/', 'trump:', 'clinton:', ['holt:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list  ('https://debates.org/voter-education/debate-transcripts/october-9-2016-debate-transcript/', 'trump:', 'clinton:', ['cooper:','raddatz:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list('https://debates.org/voter-education/debate-transcripts/october-19-2016-debate-transcript/', 'trump:', 'clinton:', ['wallace:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/september-29-2020-debate-transcript/', 'biden:', 'trump:', ['wallace:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list  ('https://www.debates.org/voter-education/debate-transcripts/october-22-2020-debate-transcript/', 'biden:', 'trump:', ['welker:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 


out_str = " "

sent1 = vader.polarity_scores(out_str.join(debateArrSent[0]))
sent2 = vader.polarity_scores(out_str.join(debateArrSent[1]))

print('Winning Candidates')
print(sent1)
print('Losing Candidates')
print(sent2)
# Out:
# Winning Candidates
# {'neg': 0.086, 'neu': 0.773, 'pos': 0.142, 'compound': 1.0}
# Losing Candidates
# {'neg': 0.083, 'neu': 0.773, 'pos': 0.144, 'compound': 1.0}

# %%
count = 0
total = 0
for word in debateArrSent[0]:
    total += len(word)
    count += 1
    
print('Winning Candidates: ' + str(float(total/count)))

count = 0
total = 0
for word in debateArrSent[1]:
    total += len(word)
    count += 1
    
    
print('Losing Candidates ' + str(float(total/count)))
# Out:
# Winning Candidates: 4.347268518729053
# Losing Candidates 4.354639316239316

# %%
import requests, re, nltk
from bs4 import BeautifulSoup
from nltk import clean_html
from collections import Counter
import operator

# We most likely would like to remove html markup
def cleanHtml (html):
    from bs4 import BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')
    return soup .get_text()

# We also want to remove special characters, quotes, etc. from each word
def cleanWord (w):
    # r in r'[.,"\']' tells to treat \ as a regular character 
    # but we need to escape ' with \'
    # any character between the brackets [] is to be removed 
    wn = re.sub('[\–,"\.\'&\|@>*;/=]', "", w)
    # get rid of numbers
    return re.sub('^[0-9\.]*$', "", wn)

def debate_word_list (URL, name1, name2, modList):
    # first get the web page
    r = requests .get(URL)
    
    # Now clean
    # remove html markup
    t = cleanHtml (r .text) .lower()
    
    # split string into an array of words using any sequence of spaces "\s+" 
    wds = re .split('\s+',t)
    
    
    
    # remove periods, commas, etc stuck to the edges of words
    for i in range(len(wds)):
        wds[i] = cleanWord (wds [i])
        
    name1Arr = []
    name2Arr = []
    switcher = 3
            
    for i in range(len(wds)):
        if wds[i] == name1:
            switcher = 1
            
        elif wds[i] == name2:
            switcher = 2
            
        elif wds[i] in modList:
            switcher = 3
            
        else:
            if switcher == 1:
                name1Arr.append(wds[i])
                
            elif switcher == 2:
                name2Arr.append(wds[i])
                
    return [name1Arr, name2Arr]

debateArrSent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/september-26-1960-debate-transcript/', "kennedy:", "nixon:", ['smith:', 'vanocur:', 'novins:', 'warren:', 'fleming:'])

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-7-1960-debate-transcript/', "kennedy:", "nixon:", ['mcgee:', 'nivem:', 'morgan:', 'spivak:', 'levy:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-13-1960-debate-transcript/', "kennedy:", "nixon:", ['shadel:', 'mcgee:', 'fremd:', 'cater:', 'drummond:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-21-1960-debate-transcript/', "kennedy:", "nixon:", ['howe:', 'singiser:', 'cronkite:', 'chancellor:'])                
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/september-23-1976-debate-transcript/', "carter:", "ford:", ['reynolds:', 'newman:', 'gannon:', 'drew:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-6-1976-debate-transcript/', "carter:", "ford:", ['valeriani:', 'frederick:', 'frankel:', 'trewhitt:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-22-1976-debate-transcript/', "carter:", "ford:", ['walters:', 'kraft:', 'maynard:', 'nelson:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-28-1980-debate-transcript/', "carter:", "reagan:", ['hinerfeld:', 'stone:', 'smith:', 'ellis:', 'hilliard:', 'walters:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debate2ArrSent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-7-1984-debate-transcript/', "mondale:", "president:", ['wieghart:', 'walters:', 'sawyer:', 'barnes:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-21-1984-debate-transcript/', "mondale:", "president:", ['ridings:', 'newman:', 'geyer:', 'kalb:', 'kondracke:', 'audience member:', 'trewhitt:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/september-25-1988-debate-transcript/', "dukakis:", "bush:", ['lehrer:', 'mashek:', 'groer:', 'jennings:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-13-1988-debate-transcript/', "dukakis:", "bush:", ['shaw:', 'compton:', 'warner:', 'mitchell:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-11-1992-first-half-debate-transcript/',  "clinton:", "bush:", ['lehrer:', 'compton:', 'sander vanocur:', 'vanocur:', 'mashek:', "perot:"])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-11-1992-second-half-debate-transcript/',  "clinton:", "bush:", ['lehrer:', 'compton:', 'sander vanocur:', 'vanocur:', 'perot:','mashek:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-15-1992-first-half-debate-transcript/',  "clinton:", "bush:", ['carole simpson:', 'audience question:', 'simpson:', 'perot:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-11-1992-second-half-debate-transcript/',  "clinton:", "bush:", ['carole simpson:', 'audience question:', 'simpson:', "perot:"])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-6-1996-debate-transcript/', 'clinton:', 'dole:', ['lehrer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-6-1996-debate-transcript/', 'clinton:', 'dole:', ['lehrer:', 'ms. mcafee:', 'dr. berkley:', 'mr. milligan:', 'ms. kelly:', 'mr. delgado:', 'mr. fleck:', 
'ms. gonzalez:', 'ms. johnson:', 'ms. naudin:', 'ms. sanders:', 'mr. david:', 'mr. burns:', 'ms. giannotti:', 'mr. goldfarb:', 'ms. strategos:', 'MS. O’CONNOR:', 'MS. SIEFERT:', 'MR. SMITH:', 'MR. KITE:', 'ms. dube:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-3-2000-transcript/', 'gore:', 'bush:', ['moderator:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-11-2000-debate-transcript/', 'gore:', 'bush:', ['moderator:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-17-2000-debate-transcript/', 'gore:', 'bush:', ['moderator:', 'member of audience:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/september-30-2004-debate-transcript/', 'kerry:', 'bush:', ['lehrer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-8-2004-debate-transcript/', 'kerry:', 'bush:', ['gibson:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/october-13-2004-debate-transcript/', 'kerry:', 'bush:', ['schieffer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/2008-debate-transcript/', 'obama:', 'mccain:', ['lehrer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list  ('https://www.debates.org/voter-education/debate-transcripts/october-7-2008-debate-transcrip/', 'obama:', 'mccain:', ['brokaw:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list('https://www.debates.org/voter-education/debate-transcripts/october-15-2008-debate-transcript/', 'obama:', 'mccain:', ['schieffer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/october-3-2012-debate-transcript/', 'obama:', 'romney:', ['lehrer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list  ('https://debates.org/voter-education/debate-transcripts/october-16-2012-the-second-obama-romney-presidential-debate/', 'obama:', 'romney:', ['crowley:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list('https://debates.org/voter-education/debate-transcripts/october-22-2012-the-third-obama-romney-presidential-debate/', 'obama:', 'romney:', ['schieffer:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://debates.org/voter-education/debate-transcripts/september-26-2016-debate-transcript/', 'clinton:', 'trump:', ['holt:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list  ('https://debates.org/voter-education/debate-transcripts/october-9-2016-debate-transcript/', 'clinton:', 'trump:', ['cooper:','raddatz:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list('https://debates.org/voter-education/debate-transcripts/october-19-2016-debate-transcript/', 'clinton:', 'trump:', ['wallace:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list ('https://www.debates.org/voter-education/debate-transcripts/september-29-2020-debate-transcript/', 'biden:', 'trump:', ['wallace:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 

debateArr2Sent = debate_word_list  ('https://www.debates.org/voter-education/debate-transcripts/october-22-2020-debate-transcript/', 'biden:', 'trump:', ['welker:'])
debateArrSent[0] += debateArr2Sent[0] 
debateArrSent[1] += debateArr2Sent[1] 


out_str = " "

sent1 = vader.polarity_scores(out_str.join(debateArrSent[0]))
sent2 = vader.polarity_scores(out_str.join(debateArrSent[1]))

print('Democrats')
print(sent1)
print('Republicans')
print(sent2)
# Out:
# Democrats
# {'neg': 0.086, 'neu': 0.774, 'pos': 0.14, 'compound': 1.0}
# Republicans
# {'neg': 0.082, 'neu': 0.772, 'pos': 0.147, 'compound': 1.0}

# %%
count = 0
total = 0
for word in debateArrSent[0]:
    total += len(word)
    count += 1
    
print('Democrats: ' + str(float(total/count)))

count = 0
total = 0
for word in debateArrSent[1]:
    total += len(word)
    count += 1
    
    
print('Republicans ' + str(float(total/count)))
# Out:
# Democrats: 4.3845054900200005
# Republicans 4.317131587006303
